# %%
# !pip install gradio reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.8 MB/s eta 0:00:00
# ...

# %%
import ast
import gradio as gr
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet

# %%
def generate_docstring(code):
    tree = ast.parse(code)
    output = ""

    for node in ast.walk(tree):
        if isinstance(node, ast.FunctionDef):
            func_name = node.name
            params = [arg.arg for arg in node.args.args]

            output += f"\nFunction: {func_name}\n"
            output += "Parameters:\n"

            for param in params:
                output += f" - {param}: Description needed\n"

            output += "Returns:\n - Description of return value\n"
            output += "-"*40 + "\n"

    return output

# %%
def doc_gen_interface(code):
    return generate_docstring(code)

interface = gr.Interface(
    fn=doc_gen_interface,
    inputs=gr.Textbox(lines=15, label="Paste Python Code Here"),
    outputs=gr.Textbox(label="Generated Docstring"),
    title="Doc-Genie",
    description="Professional Python Function Docstring Generator using AST"
)

interface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://71f801c9b5db46ff0c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://71f801c9b5db46ff0c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
